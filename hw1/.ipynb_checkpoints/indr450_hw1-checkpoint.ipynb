# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
plt.style.use('ggplot')

# %% [markdown]
# <h1>Question 1</h1>

# %%
df = pd.read_csv("CoffeePrice.csv", header = None)
df.columns = ["month", "price"]

month = df.month
price = df.price

# %% [markdown]
# Raw Data Plot

# %%
fig, ax = plt.subplots(figsize= (10,6))
ax.plot(month, price, label = "Coffee Price")
ax.legend()
ax.set_xticks([12*i for i in range(int(len(price)/12) + 1)])
for label in ax.get_xticklabels():
    label.set_rotation(45)
plt.show()

# %% [markdown]
# Error Functions

# %%
def MAE(sales, forecast):
    error = sales - forecast
    return np.mean(np.abs(error))
def MAPE(sales, forecast):
    error = sales - forecast
    return np.mean(np.abs(error / sales))
def RMSE(sales, forecast):
    error = sales - forecast
    return np.sqrt(np.mean(np.square(error)))

# %% [markdown]
# Naive Forecast with Errors

# %%
naive_forecast = np.array([price[i-1] for i in range(1,len(price))])
print("Naive Forecast MAE from 1991 to 2020:", MAE(price[12:372], naive_forecast[11:371]))
print("Naive Forecast MAPE from 1991 to 2020:", MAPE(price[12:372], naive_forecast[11:371]))
print("Naive Forecast RMSE from 1991 to 2020:", RMSE(price[12:372], naive_forecast[11:371]))
# Out:
# Naive Forecast MAE from 1991 to 2020: 2.7447940745555557
# Naive Forecast MAPE from 1991 to 2020: 0.03563979274636223
# Naive Forecast RMSE from 1991 to 2020: 4.13839665488288

# %% [markdown]
# Five Moving Average Forecast with Errors

# %%
five_ma_forecast = np.array([(price[i-5]+price[i-4]+price[i-3]
                              +price[i-2]+price[i-1])/5 
                             for i in range(5,len(price))])
print("Five MA Forecast MAE from 1991 to 2020:", MAE(price[12:372], five_ma_forecast[7:367]))
print("Five MA Forecast MAPE from 1991 to 2020:", MAPE(price[12:372], five_ma_forecast[7:367]))
print("Five MA Forecast RMSE from 1991 to 2020:", RMSE(price[12:372], five_ma_forecast[7:367]))
# Out:
# Five MA Forecast MAE from 1991 to 2020: 4.961328926305556
# Five MA Forecast MAPE from 1991 to 2020: 0.06356983921661971
# Five MA Forecast RMSE from 1991 to 2020: 7.363141715664006

# %%
confidence = 0.95 ## Confidence for our prediction intervals

# %% [markdown]
# Lower and Upper Bounds for Five MA Forecast

# %%
difference = st.norm.ppf((1+confidence)/2) * RMSE(price[12:372], five_ma_forecast[7:367])
five_ma_forecast_lower = five_ma_forecast - difference
five_ma_forecast_upper = five_ma_forecast + difference

# %%
fig, ax = plt.subplots(figsize= (10,6))
ax.plot(month[372:384], five_ma_forecast_lower[367:379], label = "lower bound")
ax.plot(month[372:384], five_ma_forecast_upper[367:379], label = "upper bound")
ax.plot(month[372:384], price[372:384], label = "real price")
ax.legend()
ax.set_title("five moving average forecast pred intervals in 2021")
plt.show()

# %% [markdown]
# Parameter Optimization for ES

# %%
es_RMSE = {}

for j in range(10):
    alpha = 0.1*(j+1)
    es_forecast = np.zeros(len(price))
    es_forecast[0] = price[0]
    for i in range(1, len(price)):
        es_forecast[i] = alpha * price[i-1] + (1-alpha) * es_forecast[i-1]
    es_RMSE[alpha] = RMSE(price[12:372], es_forecast[12:372])
    
es_RMSE = {k: v for k, v in sorted(es_RMSE.items(), key=lambda item: item[1])}
alpha_star = list(es_RMSE.keys())[0]
print(alpha_star)
# Out:
# 1.0

# %%
es_forecast = np.zeros(len(price))
es_forecast[0] = price[0]
for i in range(1, len(price)):
    es_forecast[i] = alpha_star * price[i-1] + (1-alpha_star) * es_forecast[i-1]

print("ES Forecast MAE from 1991 to 2020:", MAE(price[12:372], es_forecast[12:372]))
print("ES Forecast MAPE from 1991 to 2020:", MAPE(price[12:372], es_forecast[12:372]))
print("ES Forecast RMSE from 1991 to 2020:", RMSE(price[12:372], es_forecast[12:372]))
# Out:
# ES Forecast MAE from 1991 to 2020: 2.7447940745555557
# ES Forecast MAPE from 1991 to 2020: 0.03563979274636223
# ES Forecast RMSE from 1991 to 2020: 4.13839665488288

# %% [markdown]
# Lower and Upper Bounds for Five ES Forecast

# %%
difference = st.norm.ppf((1+confidence)/2) * RMSE(price[12:372], es_forecast[12:372])
es_forecast_lower = es_forecast - difference
es_forecast_upper = es_forecast + difference

# %%
fig, ax = plt.subplots(figsize= (10,6))
ax.plot(month[372:384], es_forecast_lower[372:384], label = "lower bound")
ax.plot(month[372:384], es_forecast_upper[372:384], label = "upper bound")
ax.plot(month[372:384], price[372:384], label = "real price")
ax.legend()
ax.set_title("es forecast pred intervals in 2021")
plt.show()

# %% [markdown]
# Naive Forecast with trend and Errors

# %%
naive_forecast_with_trend = np.array([price[i-1]+price[i-2]-price[i-3] for i in range(3,len(price))])
print("Naive Forecast with trend MAE from 1991 to 2020:", MAE(price[12:372], naive_forecast_with_trend[9:369]))
print("Naive Forecast with trend MAPE from 1991 to 2020:", MAPE(price[12:372], naive_forecast_with_trend[9:369]))
print("Naive Forecast with trend RMSE from 1991 to 2020:", RMSE(price[12:372], naive_forecast_with_trend[9:369]))
# Out:
# Naive Forecast with trend MAE from 1991 to 2020: 3.9266112891944456
# Naive Forecast with trend MAPE from 1991 to 2020: 0.05124078373307825
# Naive Forecast with trend RMSE from 1991 to 2020: 5.410511999371555

# %% [markdown]
# Lower and Upper Bounds for Naive Forecast with trend

# %%
difference = st.norm.ppf((1+confidence)/2) * RMSE(price[12:372], naive_forecast_with_trend[9:369])
naive_forecast_with_trend_lower = naive_forecast_with_trend - difference
naive_forecast_with_trend_upper = naive_forecast_with_trend + difference

# %%
fig, ax = plt.subplots(figsize= (10,6))
ax.plot(month[372:384], naive_forecast_with_trend_lower[369:381], label = "lower bound")
ax.plot(month[372:384], naive_forecast_with_trend_upper[369:381], label = "upper bound")
ax.plot(month[372:384], price[372:384], label = "real price")
ax.legend()
ax.set_title("naive forecast with trend pred intervals in 2021")
plt.show()

# %%
alpha = 0.7
beta = 0.2
smoothed_trend_forecast = np.zeros(len(price))
smoothed_trend_forecast[0] = price[0]
slope = np.array([0] + [price[i] - price[i-1] for i in range(1,len(price))])
slope_hat = np.zeros(len(slope))
slope_hat[0] = slope[0]
for i in range(1, len(price)):
    smoothed_trend_forecast[i] = alpha * price[i-1] + (1-alpha) * smoothed_trend_forecast[i-1] 
    + beta * slope[i-1] + (1-beta) * slope_hat[i-1]
    slope_hat[i] = smoothed_trend_forecast[i] - smoothed_trend_forecast[i-1]

# %%
print("Smoothed Trend Forecast MAE from 1991 to 2020:", MAE(price[12:372], smoothed_trend_forecast[12:372]))
print("Smoothed Trend Forecast MAPE from 1991 to 2020:", MAPE(price[12:372], smoothed_trend_forecast[12:372]))
print("Smoothed Trend Forecast RMSE from 1991 to 2020:", RMSE(price[12:372], smoothed_trend_forecast[12:372]))
# Out:
# Smoothed Trend Forecast MAE from 1991 to 2020: 3.1081054688421723
# Smoothed Trend Forecast MAPE from 1991 to 2020: 0.040283113971996895
# Smoothed Trend Forecast RMSE from 1991 to 2020: 4.66325308314243

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.plot(price)
ax.plot(smoothed_trend_forecast)
plt.show()

# %% [markdown]
# Lower and Upper Bounds for Smoothed Trend Forecast

# %%
difference = st.norm.ppf((1+confidence)/2) * RMSE(price[12:372], smoothed_trend_forecast[12:372])
smoothed_trend_forecast_lower = smoothed_trend_forecast - difference
smoothed_trend_forecast_upper = smoothed_trend_forecast + difference

# %%
fig, ax = plt.subplots(figsize= (10,6))
ax.plot(month[372:384], smoothed_trend_forecast_lower[372:384], label = "lower bound")
ax.plot(month[372:384], smoothed_trend_forecast_upper[372:384], label = "upper bound")
ax.plot(month[372:384], price[372:384], label = "real price")
ax.legend()
ax.set_title("Smoothed Trend Forecast pred intervals in 2021")
plt.show()

# %%
double_es_RMSE = {}
k = 1
for i in range(10):
    for j in range(10):
        alpha = 0.1*(i+1)
        beta = 0.1*(j+1)
        level = np.zeros(len(price))
        trend = np.zeros(len(price))
        level[0] = price[0]
        trend[0] = (price[len(price)-1] - price[0]) / (len(price) - 1)
        for m in range(1, len(price)):
            level[m] = alpha * price[m] + (1-alpha) * (level[m-1] + trend[m-1])
            trend[m] = beta * (level[m] - level[m-1]) + (1-beta) * trend[m-1]
        double_es_forecast = level + k * trend
        double_es_RMSE[(alpha,beta)] = RMSE(price[12:-12], double_es_forecast[13-k:-11-k])

from math import isnan, isinf
double_es_RMSE = {k: double_es_RMSE[k] for k in double_es_RMSE if not isnan(double_es_RMSE[k]) and not isinf(double_es_RMSE[k])}
double_es_RMSE = {k: v for k, v in sorted(double_es_RMSE.items(), key=lambda item: item[1])}
alpha_star = list(double_es_RMSE.keys())[0][0]
beta_star = list(double_es_RMSE.keys())[0][1]
print(alpha_star, beta_star)
# Out:
# 1.0 0.1

# %%
level = np.zeros(len(price))
trend = np.zeros(len(price))
level[0] = price[0]
trend[0] = (price[len(price)-1] - price[0]) / (len(price) - 1)
for m in range(1, len(price)):
    level[m] = alpha_star * price[m] + (1-alpha_star) * (level[m-1] + trend[m-1])
    trend[m] = beta_star * (level[m] - level[m-1]) + (1-beta_star) * trend[m-1]
double_es_forecast = level + k * trend

# %%
plt.plot(double_es_forecast)
plt.plot(price)
plt.show()

# %%
print("Double ES 1 month ahead Forecast MAE in 2015:", MAE(price[-12:], double_es_forecast[-11-k:len(double_es_forecast)-k+1]))
print("Double ES 1 month ahead Forecast MAPE in 2015:", MAPE(sales[-12:], double_es_forecast[-11-k:len(double_es_forecast)-k+1]))
print("Double ES 1 month ahead Forecast RMSE in 2015:", RMSE(sales[-12:], double_es_forecast[-11-k:len(double_es_forecast)-k+1]))
# Out:
# Double ES 1 month ahead Forecast MAE in 2015: 1.662166365196601
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3c/7zgkbng12bl6ngq2h3glc2lw0000gn/T/ipykernel_1291/4150544174.py in <module>
#       1 print("Double ES 1 month ahead Forecast MAE in 2015:", MAE(price[-12:], double_es_forecast[-11-k:len(double_es_forecast)-k+1]))
# ----> 2 print("Double ES 1 month ahead Forecast MAPE in 2015:", MAPE(sales[-12:], double_es_forecast[-11-k:len(double_es_forecast)-k+1]))
#       3 print("Double ES 1 month ahead Forecast RMSE in 2015:", RMSE(sales[-12:], double_es_forecast[-11-k:len(double_es_forecast)-k+1]))
#
# NameError: name 'sales' is not defined

# %% [markdown]
# Parameter Optimization for 6 month ahead forecast

# %%
six_month_ahead_RMSE = {}
k = 6
for i in range(10):
    for j in range(10):
        alpha = 0.1*(i+1)
        beta = 0.1*(j+1)
        six_month_ahead_forecast = np.zeros(len(price))
        for m in range(k+1):
            six_month_ahead_forecast[m] = price[m]
        slope = np.array([0] + [price[i] - price[i-1] for i in range(1,len(price))])
        slope_hat = np.zeros(len(slope))
        slope_hat[0] = slope[0]
        for i in range(1, len(price)):
            try:
                six_month_ahead_forecast[i+k] = alpha * price[i-1] + (1-alpha) * six_month_ahead_forecast[i-1] 
                + (k+1) * (beta * slope[i-1] + (1-beta) * slope_hat[i-1])
                slope_hat[i] = six_month_ahead_forecast[i] - six_month_ahead_forecast[i-1]
            except:
                six_month_ahead_forecast = np.append(six_month_ahead_forecast, alpha_star * price[i-1] + (1-alpha_star) * six_month_ahead_forecast[i-1] 
                + (k+1) * (beta_star * slope[i-1] + (1-beta_star) * slope_hat[i-1]))
        six_month_ahead_RMSE[(alpha,beta)] = RMSE(price[12:372], six_month_ahead_forecast[12:372])
        
six_month_ahead_RMSE = {k: v for k, v in sorted(six_month_ahead_RMSE.items(), key=lambda item: item[1])}
alpha_star = list(six_month_ahead_RMSE.keys())[0][0]
beta_star = list(six_month_ahead_RMSE.keys())[0][1]
print("Alpha star: ", alpha_star)
print("Beta star: ", beta_star)

# %%
six_month_ahead_forecast = np.zeros(len(price))
for m in range(k+1):
    six_month_ahead_forecast[m] = price[m]
slope = np.array([0] + [price[i] - price[i-1] for i in range(1,len(price))])
slope_hat = np.zeros(len(slope))
slope_hat[0] = slope[0]
for i in range(1, len(price)):
    try:
        six_month_ahead_forecast[i+k] = alpha_star * price[i-1] + (1-alpha_star) * six_month_ahead_forecast[i-1] 
        + (k+1) * (beta_star * slope[i-1] + (1-beta_star) * slope_hat[i-1])
        slope_hat[i] = six_month_ahead_forecast[i] - six_month_ahead_forecast[i-1]
    except:
        six_month_ahead_forecast = np.append(six_month_ahead_forecast, alpha_star * price[i-1] + (1-alpha_star) * six_month_ahead_forecast[i-1] 
        + (k+1) * (beta_star * slope[i-1] + (1-beta_star) * slope_hat[i-1]))

# %%
fig, ax = plt.subplots(figsize= (20,10))
ax.plot(six_month_ahead_forecast, label = "Six month ahead forecast", color = "blue")
ax.plot(price, label = "Real price", color = "red")
ax.legend()
plt.show()

# %% [markdown]
# Double ES Forecast Errors

# %%
print("6 month ahead Forecast MAE from 1991 to 2020:", MAE(price[12:372], six_month_ahead_forecast[12:372]))
print("6 month ahead Forecast MAPE from 1991 to 2020:", MAPE(price[12:372], six_month_ahead_forecast[12:372]))
print("6 month ahead Forecast RMSE from 1991 to 2020:", RMSE(price[12:372], six_month_ahead_forecast[12:372]))

# %%
len(six_month_ahead_forecast)

# %% [markdown]
# 6-month ahead forecasts from January 2021 to June 2022

# %%
jan21_jun22_forecast = six_month_ahead_forecast[372:390]

# %%
jan21_jun22_forecast

# %% [markdown]
# <h1>Question 2</h1>

# %% [markdown]
# Additional imports

# %%
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# 500 AR-1 Generalizations

# %%
Y = np.zeros(500)
np.random.seed(23) ## adding a seed so that the result shouldn't change in each run
Y[0] = 50+np.random.normal(0,20)
for i in range(1,len(Y)):
    Y[i] = 50 + 0.6 * Y[i-1] + np.random.normal(0,20)

# %% [markdown]
# Time series plot of AR-1 Generalizations

# %%
fig, ax = plt.subplots(figsize= (20,6), dpi = 200)
ax.plot(Y)
plt.show()

# %% [markdown]
# ACF plot

# %%
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})
plot_acf(Y[100:])
plt.show()

# %% [markdown]
# RMSE function

# %% [markdown]
# Naive forecast and RMSE from period 100

# %%
naive_forecast = np.array([Y[i-1] for i in range(1,len(Y))])
print("RMSE starting from period 100:", RMSE(Y[100:], naive_forecast[99:]))

# %% [markdown]
# <h1>Question 3</h1>

# %% [markdown]
# Autocorrelation Function plot

# %%
plot_acf(price,lags = 48)
plt.show()

# %% [markdown]
# Partial Autocorrelation plot

# %%
plot_pacf(price)
plt.show()

# %% [markdown]
# Difference data and ACF plot

# %%
difference = np.array([price[i] - price[i-1] for i in range(1,len(price))])
plot_acf(difference,lags = 48)
plt.show()

# %% [markdown]
# PACF plot

# %%
plot_pacf(difference)
plt.show()
